# %%
import pandas as pd

# %%
df = pd.read_csv('../HC Davos_HC Dynamo Pardubice_Wisehockey_Match_Events_31_12_2023.csv')

# %%
df.head()
# Out:
#    Period  MatchClock      Timestamp         EventType TeamStrengthType  \
# 0       1           0  1704021018760           Faceoff     FullStrength
# 1       1           0  1704021018760       PuckControl     FullStrength
# 2       1           1  1704021020080       PuckControl     FullStrength
# 3       1           1  1704021020100       PuckControl     FullStrength
# 4       1           1  1704021020580  BluelineCrossing     FullStrength
#
#   TeamStrength HomeGoalieOnIce AwayGoalieOnIce EventPosition  \
# 0          5v5            True            True   NeutralZone
# 1          5v5            True            True   NeutralZone
# 2          5v5            True            True   NeutralZone
# 3          5v5            True            True   NeutralZone
# 4          5v5            True            True   NeutralZone
#
#   EventStartCoordinate  ... StartPlayerDirection3  StartPlayerDirection4  \
# 0                  NaN  ...                   NaN                    NaN
# ...

# %%
2 Drittel
Timestamp 988 -> 1001

# %%
df_Period2 = df[df['Period'] == 2]

# %%
df3 = df_Period2[df_Period2['MatchClock'] >= 988]

# %%
df4 = df3[df3['MatchClock'] <= 1001]
df4
# Out:
#       Period  MatchClock      Timestamp         EventType TeamStrengthType  \
# 2649       2         988  1704026093174              Goal    AwayPowerplay
# 2650       2         988  1704026093360       PuckControl    AwayPowerplay
# 2651       2         988  1704026094020    StoppageOfPlay              NaN
# 2652       2         988  1704026142900           Faceoff     FullStrength
# 2653       2         988  1704026142900       PuckControl     FullStrength
# 2654       2         990  1704026144060       PuckControl     FullStrength
# 2655       2         990  1704026144580  BluelineCrossing     FullStrength
# 2656       2         990  1704026144860              Pass     FullStrength
# 2657       2         990  1704026144880       PuckControl     FullStrength
# 2658       2         990  1704026144940  BluelineCrossing     FullStrength
# 2659       2         991  1704026145940       PuckControl     FullStrength
# ...
